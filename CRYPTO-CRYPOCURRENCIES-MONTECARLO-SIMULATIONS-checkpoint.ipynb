# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

###load the dataset
df = pd.read_csv(r"C:\Users\user\Downloads\BTC-USD.csv")

####show mew the first 100
print(df.head(100))
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1   2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2   2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3   2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4   2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# ..         ...         ...         ...         ...         ...         ...
# 95  2014-12-21  329.542999  329.628998  318.903015  320.842987  320.842987
# 96  2014-12-22  321.067993  334.117004  320.424988  331.885986  331.885986
# 97  2014-12-23  332.016998  336.286987  329.601990  334.571991  334.571991
# 98  2014-12-24  334.385010  334.740997  321.356995  322.533997  322.533997
# 99  2014-12-25  322.286011  322.670013  316.958008  319.007996  319.007996
#
#       Volume
# 0   21056800
# 1   34483200
# 2   37919700
# ...

# %%
import pandas as pd
import numpy as np

#Asuming your dataframe is called df and closed column has price
df['Daily_Return'] = df['Close'].pct_change()

##Drop NaN values that result from pct_change
returns = df['Daily_Return'].dropna()

print(returns.head())
# Out:
# 1   -0.071926
# 2   -0.069843
# 3    0.035735
# 4   -0.024659
# 5    0.008352
# Name: Daily_Return, dtype: float64

# %%
mean_return = returns.mean()
std_dev_return = returns.std()

print(f"Mean Daily return:{mean_return}")
print(f"Standard deviation of daily returns: {std_dev_return}")
# Out:
# Mean Daily return:0.002412396468582276
# Standard deviation of daily returns: 0.03883477526381458

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Calculate daily returns
df['Daily_Return'] = df['Close'].pct_change()
returns = df['Daily_Return'].dropna()

# Calculate mean and std dev
mean_return = returns.mean()
std_dev_return = returns.std()

# Monte Carlo parameters
num_simulations = 1000
num_days = 30
last_price = df['Close'].iloc[-1]

# Run simulations
simulation_df = pd.DataFrame()

for sim in range(num_simulations):
    prices = [last_price]
    for day in range(num_days):
        next_price = prices[-1] * (1 + np.random.normal(mean_return, std_dev_return))
        prices.append(next_price)
    simulation_df[sim] = prices

# Plot the simulations
plt.figure(figsize=(10, 6))
plt.plot(simulation_df)
plt.title('Monte Carlo Simulation of Cryptocurrency Price Over 30 Days')
plt.xlabel('Day')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16296\3031845391.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   simulation_df[sim] = prices
# C:\Users\user\AppData\Local\Temp\ipykernel_16296\3031845391.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   simulation_df[sim] = prices
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from xgboost import XGBClassifier

# Create target variable: 1 if next day close > current close
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# Drop last row (since no next day data)
df = df.dropna()

# Features
features = ['Open', 'High', 'Low', 'Close', 'Volume']
X = df[features]
y = df['Target']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression
log_model = LogisticRegression()
log_model.fit(X_train_scaled, y_train)
y_pred_log = log_model.predict(X_test_scaled)

print("Logistic Regression Results:")
print(confusion_matrix(y_test, y_pred_log))
print(classification_report(y_test, y_pred_log))

# XGBoost
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)

print("XGBoost Results:")
print(confusion_matrix(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb))
# Out:
# Logistic Regression Results:
# [[241  11]
#  [269  22]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.96      0.63       252
#            1       0.67      0.08      0.14       291
#
#     accuracy                           0.48       543
#    macro avg       0.57      0.52      0.38       543
# weighted avg       0.58      0.48      0.37       543
#
# XGBoost Results:
# [[233  19]
#  [260  31]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.92      0.63       252
#            1       0.62      0.11      0.18       291
#
#     accuracy                           0.49       543
#    macro avg       0.55      0.52      0.40       543
# weighted avg       0.55      0.49      0.39       543
# C:\Users\user\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [03:10:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
# ...
